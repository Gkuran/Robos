# %% [markdown]
# Passo 1: Entrar no sistema da empresa (Link do Drive);
# Passo 2: Navegar no sistema (Até a pasta exportar);
# Passo 3: Fazer o download da base de vendas;
# Passo 4: Importar a base de vendas para Python;
# Passo 5: Calcular o faturamento e quantidade de produtos vendidos;
# Passo 6: Enviar email pra diretoria.

# %%
import pyautogui
import pyperclip
import time
import pandas as carro

pyautogui.PAUSE = 1 #Tempo/Delay

#Passo 1: Entrar no sistema da empresa (Link do Drive);

#pyautogui.press('win')
#pyautogui.write('opera')
#pyautogui.press('enter')

pyautogui.hotkey('ctrl', 't') #Atalho default que abre aba nova no navegador;
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing')
pyautogui.hotkey('ctrl', 'v') #Cola o Link copiado pelo pyperclip
pyautogui.press('enter') #'Entra no sistema'

# Carrega o Sistema ...
time.sleep(5)

# Passo 2: Navegar no sistema (Até a pasta exportar);
pyautogui.click(x=999, y=309, clicks = 2)
time.sleep(2)
# Passo 3: Fazer o download da base de vendas;
pyautogui.click(x=1007, y=308)
pyautogui.click(x=1661, y=215)
pyautogui.click(x=1397, y=583)

# Passo 4: Importar a base de vendas para Python;
#db = carro.read_excel('C:/Users/Gabri/Downloads/Vendas - Dez.xlsx')

# %%
# Passo 4: Importar a base de vendas para Python;
import pandas as pd

db = pd.read_excel('C:/Users/Gabri/Downloads/Vendas - Dez.xlsx')
display(db)

# Passo 5: Calcular o faturamento e quantidade de produtos vendidos (Indicadores);
faturamento = db['Valor Final'].sum()
quantidade  = db['Quantidade'].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Passo 6: Enviar email pra diretoria.
link = 'https://mail.google.com/mail/u/0/#inbox'
# Abrir o email:
pyautogui.hotkey('ctrl', 't')
pyperclip.copy('https://mail.google.com/mail/u/0/#inbox')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')

time.sleep(5)
# Clicka no botão de escrever e-mail;
pyautogui.click(x=739, y=224)

# Destinatário;
pyautogui.write('gabrielkuran42@gmail.com')
pyautogui.press('tab')
pyautogui.press('tab')

# Assunto;
pyperclip.copy('Relatório de vendas')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

# Escreve o e-mail;

text = f"""
Prezados, bom dia

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs"""

pyperclip.copy(text)
pyautogui.hotkey('ctrl', 'v')

pyautogui.hotkey("ctrl", "enter")

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1349, y=675)
